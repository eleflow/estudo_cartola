# %%
# %run ./dataframes.ipynb

# %%
GOLEIRO = 1
ZAGUEIRO = 2
LATERAL = 3
MEIA = 4
ATACANTE = 5

# %%
df_matches, df_scouts, df_pontuacao, df_clubs, df_mandante_x_visitante, df_mandante_x_visitante_cedidos_mais_conquistados, df_visitante_x_mandante, df_visitante_x_mandante_cedidos_mais_conquistados, df_conquistados, df_cedidos, df_club_matches, df_club_matches_home_visitor = prepara_dataframes()
# Out:
# Quantidade de linhas para clubes: [(20,)]
# Quantidade de linhas para partidas: [(260,)]
# Quantidade de linhas para scouts: [(8467,)]
#
#         "Percentual de vitoria CASA:" 0.4346153846153846,
#         "Percentual de EMPATE:" 0.3153846153846154,
#         "Percentual de vitoria FORA:" 0.25
#
# None
# /tmp/ipykernel_91/3761551425.py:11: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_aux2 = df_aux.groupby(['match_id', 'round', 'home_id', 'visitor_id', 'local', 'valid',\

# %%
df_matches.head()
# Out:
#    match_id  round  home_id  visitor_id                 date   timestamp  \
# 0    287509      1      266         277  2022-04-09 16:30:00  1649532600
# 1    287515      1      373         262  2022-04-09 19:00:00  1649541600
# 2    287511      1      275         354  2022-04-09 21:00:00  1649548800
# 3    287517      1      294         290  2022-04-10 11:00:00  1649599200
# 4    287508      1      282         285  2022-04-10 16:00:00  1649617200
#
#              local  valid  home_goal  visitor_goal  year  diff_goals  \
# 0         Maracanã   True          0             0  2022           0
# 1  Antônio Accioly   True          1             1  2022           0
# 2   Allianz Parque   True          2             3  2022          -1
# 3    Couto Pereira   True          3             0  2022           3
# 4         Mineirão   True          2             0  2022           2
#
#     vencedor            datetime
# 0     EMPATE 2022-04-09 16:30:00
# 1     EMPATE 2022-04-09 19:00:00
# ...

# %%
df_scouts.head()
# Out:
#     player_name  points  id_position  id_club  has_played id_player  scout_fc  \
# 0       Rickson     1.2            4      373        True    100002       0.0
# 1  Jhojan Julio     5.2            5      277        True    100074       4.0
# 2       Zaracho     8.1            4      282        True    100079       1.0
# 3    Igor Gomes     3.2            4      276        True    100084       2.0
# 4      Pedrinho     1.5            5      327        True    100103       2.0
#
#    scout_fs  scout_pi  scout_ff  ...  round  visitor_id  home_id  home_goal  \
# 0       0.0       0.0       0.0  ...      1       262.0    373.0        1.0
# 1       4.0       2.0       0.0  ...      1       277.0    266.0        0.0
# 2       0.0       2.0       0.0  ...      1       285.0    282.0        2.0
# 3       0.0       6.0       1.0  ...      1       293.0    276.0        4.0
# 4       0.0       5.0       0.0  ...      1       327.0    314.0        1.0
#
# ...

# %%
df_pontuacao.head()
# Out:
#   id_player         time   player_name  id_club  id_position  points_casa  \
# 0    100002  Atlético-GO       Rickson      373            4          1.0
# 1    100074       Santos  Jhojan Julio      277            5         12.9
# 2    100079  Atlético-MG       Zaracho      282            4         31.1
# 3    100084    São Paulo    Igor Gomes      276            4          9.1
# 4    100103   América-MG      Pedrinho      327            5         45.7
#
#    has_played_casa  points_fora  has_played_fora  total_pontos  total_jogos
# 0              4.0          0.5              4.0           1.5          8.0
# 1              7.0         12.5              4.0          25.4         11.0
# 2              6.0         53.3              7.0          84.4         13.0
# 3             10.0         24.4             12.0          33.5         22.0
# 4              9.0         20.8             10.0          66.5         19.0

# %%
df_mandante_x_visitante.head()
# Out:
#       mandante  id_position  pontos_conquistados   visitante  pontos_cedidos  \
# 0  Atlético-MG            1                 84.0  Bragantino            95.7
# 1  Atlético-MG            2                212.5  Bragantino           203.1
# 2  Atlético-MG            3                214.1  Bragantino           158.5
# 3  Atlético-MG            4                443.4  Bragantino           328.4
# 4  Atlético-MG            5                439.7  Bragantino           294.2
#
#    cedidos_mais_conquistados
# 0                      179.7
# 1                      415.6
# 2                      372.6
# 3                      771.8
# 4                      733.9

# %%
df_mandante_x_visitante_cedidos_mais_conquistados.head()
# Out:
#       mandante  id_position  pontos_conquistados   visitante  pontos_cedidos  \
# 0  Atlético-MG            1                 84.0  Bragantino            95.7
# 1  Atlético-MG            2                212.5  Bragantino           203.1
# 2  Atlético-MG            3                214.1  Bragantino           158.5
# 3  Atlético-MG            4                443.4  Bragantino           328.4
# 4  Atlético-MG            5                439.7  Bragantino           294.2
#
#    cedidos_mais_conquistados
# 0                      179.7
# 1                      415.6
# 2                      372.6
# 3                      771.8
# 4                      733.9

# %%
df_visitante_x_mandante.head()
# Out:
#     visitante  id_position  pontos_conquistados     mandante  pontos_cedidos  \
# 0  Bragantino            1                 73.5  Atlético-MG            85.4
# 1  Bragantino            2                241.8  Atlético-MG           240.2
# 2  Bragantino            3                166.7  Atlético-MG           169.4
# 3  Bragantino            4                319.2  Atlético-MG           309.7
# 4  Bragantino            5                363.7  Atlético-MG           254.9
#
#    cedidos_mais_conquistados
# 0                      158.9
# 1                      482.0
# 2                      336.1
# 3                      628.9
# 4                      618.6

# %%
df_visitante_x_mandante_cedidos_mais_conquistados.head()
# Out:
#     visitante  id_position  pontos_conquistados     mandante  pontos_cedidos  \
# 0  Bragantino            1                 73.5  Atlético-MG            85.4
# 1  Bragantino            2                241.8  Atlético-MG           240.2
# 2  Bragantino            3                166.7  Atlético-MG           169.4
# 3  Bragantino            4                319.2  Atlético-MG           309.7
# 4  Bragantino            5                363.7  Atlético-MG           254.9
#
#    cedidos_mais_conquistados
# 0                      158.9
# 1                      482.0
# 2                      336.1
# 3                      628.9
# 4                      618.6

# %% [markdown]
# # Pontuação por times e adversarios

# %%
df_mandante_x_visitante_cedidos_mais_conquistados[
    (df_mandante_x_visitante_cedidos_mais_conquistados['id_position'] == GOLEIRO)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 24      Palmeiras            1                118.5     Juventude
# 30       Botafogo            1                 82.5    América-MG
# 6   Internacional            1                 96.2        Cuiabá
# 54          Goiás            1                111.7      Flamengo
# 12          Ceará            1                 95.7        Santos
# 18     Fluminense            1                 76.5     Fortaleza
# 0     Atlético-MG            1                 84.0    Bragantino
# 48       Coritiba            1                 74.2   Atlético-GO
# 36           Avaí            1                 58.9  Athlético-PR
# 42      São Paulo            1                 70.5   Corinthians
#
#     pontos_cedidos  cedidos_mais_conquistados
# 24           114.2                      232.7
# 30           134.7                      217.2
# 6            102.7                      198.9
# 54            86.0                      197.7
# ...

# %%
df_visitante_x_mandante_cedidos_mais_conquistados[
    (df_visitante_x_mandante_cedidos_mais_conquistados['id_position'] == GOLEIRO)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 30    América-MG            1                109.2       Botafogo
# 12        Santos            1                118.7          Ceará
# 42   Corinthians            1                110.7      São Paulo
# 36  Athlético-PR            1                122.7           Avaí
# 18     Fortaleza            1                100.0     Fluminense
# 6         Cuiabá            1                 92.1  Internacional
# 48   Atlético-GO            1                 83.2       Coritiba
# 0     Bragantino            1                 73.5    Atlético-MG
# 24     Juventude            1                 78.0      Palmeiras
# 54      Flamengo            1                 79.4          Goiás
#
#     pontos_cedidos  cedidos_mais_conquistados
# 30           117.5                      226.7
# 12           102.0                      220.7
# 42            89.7                      200.4
# 36            72.5                      195.2
# ...

# %%
df_mandante_x_visitante_cedidos_mais_conquistados[
    (df_mandante_x_visitante_cedidos_mais_conquistados['id_position'] == 2)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 25      Palmeiras            2                318.3     Juventude
# 31       Botafogo            2                214.5    América-MG
# 7   Internacional            2                247.2        Cuiabá
# 49       Coritiba            2                231.2   Atlético-GO
# 13          Ceará            2                192.6        Santos
# 43      São Paulo            2                248.9   Corinthians
# 1     Atlético-MG            2                212.5    Bragantino
# 19     Fluminense            2                175.6     Fortaleza
# 37           Avaí            2                130.0  Athlético-PR
# 55          Goiás            2                107.9      Flamengo
#
#     pontos_cedidos  cedidos_mais_conquistados
# 25           242.4                      560.7
# 31           280.0                      494.5
# 7            237.2                      484.4
# 49           219.0                      450.2
# ...

# %%
df_visitante_x_mandante_cedidos_mais_conquistados[
    (df_visitante_x_mandante_cedidos_mais_conquistados['id_position'] == 2)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 55      Flamengo            2                249.6          Goiás
# 43   Corinthians            2                289.8      São Paulo
# 31    América-MG            2                222.9       Botafogo
# 1     Bragantino            2                241.8    Atlético-MG
# 37  Athlético-PR            2                255.2           Avaí
# 19     Fortaleza            2                225.6     Fluminense
# 13        Santos            2                188.0          Ceará
# 49   Atlético-GO            2                137.2       Coritiba
# 25     Juventude            2                198.6      Palmeiras
# 7         Cuiabá            2                144.9  Internacional
#
#     pontos_cedidos  cedidos_mais_conquistados
# 55           247.6                      497.2
# 43           198.8                      488.6
# 31           261.8                      484.7
# 1            240.2                      482.0
# ...

# %%
df_mandante_x_visitante_cedidos_mais_conquistados[
    (df_mandante_x_visitante_cedidos_mais_conquistados['id_position'] == 3)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 26      Palmeiras            3                287.9     Juventude
# 8   Internacional            3                196.2        Cuiabá
# 20     Fluminense            3                210.4     Fortaleza
# 32       Botafogo            3                180.9    América-MG
# 2     Atlético-MG            3                214.1    Bragantino
# 50       Coritiba            3                136.1   Atlético-GO
# 56          Goiás            3                196.9      Flamengo
# 44      São Paulo            3                168.5   Corinthians
# 14          Ceará            3                120.0        Santos
# 38           Avaí            3                 86.5  Athlético-PR
#
#     pontos_cedidos  cedidos_mais_conquistados
# 26           210.0                      497.9
# 8            210.5                      406.7
# 20           189.5                      399.9
# 32           214.1                      395.0
# ...

# %%
df_visitante_x_mandante_cedidos_mais_conquistados[
    (df_visitante_x_mandante_cedidos_mais_conquistados['id_position'] == 3)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 44   Corinthians            3                271.5      São Paulo
# 20     Fortaleza            3                237.5     Fluminense
# 32    América-MG            3                192.4       Botafogo
# 14        Santos            3                214.3          Ceará
# 38  Athlético-PR            3                198.4           Avaí
# 8         Cuiabá            3                194.0  Internacional
# 2     Bragantino            3                166.7    Atlético-MG
# 56      Flamengo            3                162.1          Goiás
# 26     Juventude            3                133.2      Palmeiras
# 50   Atlético-GO            3                 39.3       Coritiba
#
#     pontos_cedidos  cedidos_mais_conquistados
# 44           189.9                      461.4
# 20           190.6                      428.1
# 32           199.5                      391.9
# 14           173.9                      388.2
# ...

# %%
df_mandante_x_visitante_cedidos_mais_conquistados[
    (df_mandante_x_visitante_cedidos_mais_conquistados['id_position'] == 4)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 27      Palmeiras            4                462.4     Juventude
# 3     Atlético-MG            4                443.4    Bragantino
# 45      São Paulo            4                341.4   Corinthians
# 33       Botafogo            4                308.1    América-MG
# 21     Fluminense            4                361.4     Fortaleza
# 9   Internacional            4                406.0        Cuiabá
# 51       Coritiba            4                248.7   Atlético-GO
# 39           Avaí            4                284.0  Athlético-PR
# 57          Goiás            4                281.6      Flamengo
# 15          Ceará            4                260.7        Santos
#
#     pontos_cedidos  cedidos_mais_conquistados
# 27           430.8                      893.2
# 3            328.4                      771.8
# 45           377.5                      718.9
# 33           383.4                      691.5
# ...

# %%
df_visitante_x_mandante_cedidos_mais_conquistados[
    (df_visitante_x_mandante_cedidos_mais_conquistados['id_position'] == 4)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 57      Flamengo            4                548.3          Goiás
# 45   Corinthians            4                422.2      São Paulo
# 51   Atlético-GO            4                412.3       Coritiba
# 39  Athlético-PR            4                341.7           Avaí
# 33    América-MG            4                244.8       Botafogo
# 21     Fortaleza            4                305.3     Fluminense
# 3     Bragantino            4                319.2    Atlético-MG
# 15        Santos            4                288.9          Ceará
# 9         Cuiabá            4                283.5  Internacional
# 27     Juventude            4                198.3      Palmeiras
#
#     pontos_cedidos  cedidos_mais_conquistados
# 57           390.9                      939.2
# 45           361.2                      783.4
# 51           336.2                      748.5
# 39           352.3                      694.0
# ...

# %%
df_mandante_x_visitante_cedidos_mais_conquistados[
    (df_mandante_x_visitante_cedidos_mais_conquistados['id_position'] == 5)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 52       Coritiba            5                455.3   Atlético-GO
# 28      Palmeiras            5                373.2     Juventude
# 4     Atlético-MG            5                439.7    Bragantino
# 22     Fluminense            5                423.8     Fortaleza
# 40           Avaí            5                315.7  Athlético-PR
# 10  Internacional            5                355.7        Cuiabá
# 34       Botafogo            5                305.0    América-MG
# 58          Goiás            5                351.9      Flamengo
# 16          Ceará            5                274.5        Santos
# 46      São Paulo            5                283.3   Corinthians
#
#     pontos_cedidos  cedidos_mais_conquistados
# 52           347.3                      802.6
# 28           424.2                      797.4
# 4            294.2                      733.9
# 22           284.2                      708.0
# ...

# %%
df_visitante_x_mandante_cedidos_mais_conquistados[
    (df_visitante_x_mandante_cedidos_mais_conquistados['id_position'] == 5)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 40  Athlético-PR            5                331.0           Avaí
# 16        Santos            5                401.3          Ceará
# 58      Flamengo            5                346.1          Goiás
# 52   Atlético-GO            5                261.8       Coritiba
# 34    América-MG            5                307.8       Botafogo
# 4     Bragantino            5                363.7    Atlético-MG
# 22     Fortaleza            5                269.5     Fluminense
# 46   Corinthians            5                167.7      São Paulo
# 10        Cuiabá            5                201.9  Internacional
# 28     Juventude            5                227.0      Palmeiras
#
#     pontos_cedidos  cedidos_mais_conquistados
# 40           409.2                      740.2
# 16           336.5                      737.8
# 58           349.0                      695.1
# 52           386.9                      648.7
# ...

# %% [markdown]
# # Pontuação conquistada x Pontuação cedida (casa x fora)

# %%
df_conquistados.head()
# Out:
#       mandante  id_position  pontos_conquistados   visitante  pontos_cedidos  \
# 0  Atlético-MG            1                 31.5  Bragantino            45.5
# 1  Atlético-MG            2                 92.7  Bragantino           111.2
# 2  Atlético-MG            3                120.1  Bragantino            70.3
# 3  Atlético-MG            4                235.1  Bragantino           204.8
# 4  Atlético-MG            5                225.7  Bragantino           177.1
#
#    cedidos_mais_conquistados
# 0                       77.0
# 1                      203.9
# 2                      190.4
# 3                      439.9
# 4                      402.8

# %%
df_cedidos.head()
# Out:
#     visitante  id_position  pontos_conquistados     mandante  pontos_cedidos  \
# 0  Bragantino            1                 32.0  Atlético-MG            37.9
# 1  Bragantino            2                112.0  Atlético-MG           125.6
# 2  Bragantino            3                 48.9  Atlético-MG            86.3
# 3  Bragantino            4                144.1  Atlético-MG           139.5
# 4  Bragantino            5                168.4  Atlético-MG           136.5
#
#    cedidos_mais_conquistados
# 0                       69.9
# 1                      237.6
# 2                      135.2
# 3                      283.6
# 4                      304.9

# %%
df_conquistados[
    (df_conquistados['id_position'] == GOLEIRO)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 30       Botafogo            1                 36.0    América-MG
# 24      Palmeiras            1                 53.5     Juventude
# 54          Goiás            1                 50.2      Flamengo
# 48       Coritiba            1                 55.7   Atlético-GO
# 6   Internacional            1                 50.2        Cuiabá
# 12          Ceará            1                 31.5        Santos
# 36           Avaí            1                 25.0  Athlético-PR
# 0     Atlético-MG            1                 31.5    Bragantino
# 18     Fluminense            1                 39.0     Fortaleza
# 42      São Paulo            1                 39.0   Corinthians
#
#     pontos_cedidos  cedidos_mais_conquistados
# 30            77.7                      113.7
# 24            58.0                      111.5
# 54            50.5                      100.7
# 48            43.2                       98.9
# ...

# %%
df_cedidos[
    (df_cedidos['id_position'] == GOLEIRO)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 30    América-MG            1                 52.5       Botafogo
# 12        Santos            1                 47.5          Ceará
# 24     Juventude            1                 41.0      Palmeiras
# 36  Athlético-PR            1                 62.2           Avaí
# 48   Atlético-GO            1                 45.2       Coritiba
# 18     Fortaleza            1                 41.5     Fluminense
# 42   Corinthians            1                 29.7      São Paulo
# 0     Bragantino            1                 32.0    Atlético-MG
# 6         Cuiabá            1                 41.4  Internacional
# 54      Flamengo            1                 35.4          Goiás
#
#     pontos_cedidos  cedidos_mais_conquistados
# 30            60.0                      112.5
# 12            52.5                      100.0
# 24            48.0                       89.0
# 36            20.5                       82.7
# ...

# %%
df_conquistados[
    (df_conquistados['id_position'] == 2)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 25      Palmeiras            2                163.4     Juventude
# 7   Internacional            2                128.3        Cuiabá
# 31       Botafogo            2                103.0    América-MG
# 49       Coritiba            2                160.9   Atlético-GO
# 43      São Paulo            2                151.1   Corinthians
# 13          Ceará            2                 85.9        Santos
# 37           Avaí            2                 67.8  Athlético-PR
# 1     Atlético-MG            2                 92.7    Bragantino
# 19     Fluminense            2                112.3     Fortaleza
# 55          Goiás            2                 56.9      Flamengo
#
#     pontos_cedidos  cedidos_mais_conquistados
# 25           131.0                      294.4
# 7            144.5                      272.8
# 31           164.4                      267.4
# 49            93.3                      254.2
# ...

# %%
df_cedidos[
    (df_cedidos['id_position'] == 2)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 1     Bragantino            2                112.0    Atlético-MG
# 31    América-MG            2                 90.2       Botafogo
# 19     Fortaleza            2                105.8     Fluminense
# 37  Athlético-PR            2                125.6           Avaí
# 49   Atlético-GO            2                 66.4       Coritiba
# 13        Santos            2                 71.3          Ceará
# 43   Corinthians            2                 87.2      São Paulo
# 25     Juventude            2                 84.6      Palmeiras
# 55      Flamengo            2                 62.9          Goiás
# 7         Cuiabá            2                 47.0  Internacional
#
#     pontos_cedidos  cedidos_mais_conquistados
# 1            125.6                      237.6
# 31           112.5                      202.7
# 19            95.8                      201.6
# 37            68.8                      194.4
# ...

# %%
df_conquistados[
    (df_conquistados['id_position'] == 3)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 26      Palmeiras            3                149.6     Juventude
# 50       Coritiba            3                 98.5   Atlético-GO
# 32       Botafogo            3                 91.7    América-MG
# 56          Goiás            3                 99.3      Flamengo
# 8   Internacional            3                 91.9        Cuiabá
# 20     Fluminense            3                115.5     Fortaleza
# 2     Atlético-MG            3                120.1    Bragantino
# 44      São Paulo            3                108.9   Corinthians
# 38           Avaí            3                 39.5  Athlético-PR
# 14          Ceará            3                 49.9        Santos
#
#     pontos_cedidos  cedidos_mais_conquistados
# 26           111.6                      261.2
# 50           121.2                      219.7
# 32           120.5                      212.2
# 56           107.2                      206.5
# ...

# %%
df_cedidos[
    (df_cedidos['id_position'] == 3)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 20     Fortaleza            3                115.8     Fluminense
# 44   Corinthians            3                100.9      São Paulo
# 32    América-MG            3                 77.1       Botafogo
# 38  Athlético-PR            3                105.5           Avaí
# 14        Santos            3                 79.6          Ceará
# 8         Cuiabá            3                 90.7  Internacional
# 2     Bragantino            3                 48.9    Atlético-MG
# 26     Juventude            3                 46.8      Palmeiras
# 56      Flamengo            3                 48.4          Goiás
# 50   Atlético-GO            3                 20.8       Coritiba
#
#     pontos_cedidos  cedidos_mais_conquistados
# 20            96.1                      211.9
# 44           102.9                      203.8
# 32            96.7                      173.8
# 38            64.7                      170.2
# ...

# %%
df_conquistados[
    (df_conquistados['id_position'] == 4)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 27      Palmeiras            4                287.3     Juventude
# 3     Atlético-MG            4                235.1    Bragantino
# 51       Coritiba            4                153.7   Atlético-GO
# 45      São Paulo            4                178.2   Corinthians
# 21     Fluminense            4                200.7     Fortaleza
# 9   Internacional            4                228.1        Cuiabá
# 33       Botafogo            4                150.4    América-MG
# 39           Avaí            4                163.3  Athlético-PR
# 57          Goiás            4                159.0      Flamengo
# 15          Ceará            4                125.3        Santos
#
#     pontos_cedidos  cedidos_mais_conquistados
# 27           254.4                      541.7
# 3            204.8                      439.9
# 51           272.3                      426.0
# 45           213.2                      391.4
# ...

# %%
df_cedidos[
    (df_cedidos['id_position'] == 4)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 57      Flamengo            4                245.6          Goiás
# 45   Corinthians            4                188.4      São Paulo
# 51   Atlético-GO            4                171.8       Coritiba
# 15        Santos            4                117.7          Ceará
# 21     Fortaleza            4                121.3     Fluminense
# 3     Bragantino            4                144.1    Atlético-MG
# 39  Athlético-PR            4                150.4           Avaí
# 33    América-MG            4                 92.9       Botafogo
# 9         Cuiabá            4                135.3  Internacional
# 27     Juventude            4                 86.4      Palmeiras
#
#     pontos_cedidos  cedidos_mais_conquistados
# 57           155.3                      400.9
# 45           139.6                      328.0
# 51           148.9                      320.7
# 15           180.3                      298.0
# ...

# %%
df_conquistados[
    (df_conquistados['id_position'] == 5)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#          mandante  id_position  pontos_conquistados     visitante  \
# 22     Fluminense            5                305.4     Fortaleza
# 52       Coritiba            5                270.9   Atlético-GO
# 40           Avaí            5                190.7  Athlético-PR
# 28      Palmeiras            5                182.0     Juventude
# 4     Atlético-MG            5                225.7    Bragantino
# 10  Internacional            5                209.3        Cuiabá
# 46      São Paulo            5                168.2   Corinthians
# 58          Goiás            5                160.5      Flamengo
# 16          Ceará            5                123.1        Santos
# 34       Botafogo            5                121.8    América-MG
#
#     pontos_cedidos  cedidos_mais_conquistados
# 22           160.1                      465.5
# 52           184.5                      455.4
# 40           244.8                      435.5
# 28           247.1                      429.1
# ...

# %%
df_cedidos[
    (df_cedidos['id_position'] == 5)
].sort_values(by='cedidos_mais_conquistados', ascending=False)
# Out:
#        visitante  id_position  pontos_conquistados       mandante  \
# 16        Santos            5                134.4          Ceará
# 40  Athlético-PR            5                157.0           Avaí
# 58      Flamengo            5                139.6          Goiás
# 4     Bragantino            5                168.4    Atlético-MG
# 22     Fortaleza            5                161.2     Fluminense
# 52   Atlético-GO            5                124.9       Coritiba
# 46   Corinthians            5                 58.7      São Paulo
# 34    América-MG            5                104.2       Botafogo
# 10        Cuiabá            5                 83.2  Internacional
# 28     Juventude            5                 95.6      Palmeiras
#
#     pontos_cedidos  cedidos_mais_conquistados
# 16           183.9                      318.3
# 40           154.2                      311.2
# 58           171.1                      310.7
# 4            136.5                      304.9
# ...

# %% [markdown]
# # Rascunho analise

# %%
df_club_matches.head(10)
# Out:
#    match_id  round  home_id  visitor_id           local  valid  home_goal  \
# 0    287514      1      356        1371   Castelão (CE)   True          0
# 1    287536      2     1371         266  Arena Pantanal   True          0
# 2    287564      3      286        1371  Alfredo Jaconi   True          0
# 3    287586      4     1371         373  Arena Pantanal   True          1
# 4    287632      5      277        1371    Vila Belmiro   True          4
# 5    287680      6      276        1371         Morumbi   True          2
# 6    287706      7     1371         285  Arena Pantanal   True          1
# 7    287736      8     1371         293  Arena Pantanal   True          0
# 8    287748      9      327        1371   Independência   True          2
# 9    287776     10     1371         264  Arena Pantanal  False          1
#
#    visitor_goal  year  diff_goals   vencedor            datetime  ref_id  \
# 0             1  2022          -1  VISITANTE 2022-04-10 18:00:00    1371
# ...

# %%
df_club_matches[df_club_matches['ref_result'] > 0]['ref_goals_diff'].describe()
# Out:
# count    168.000000
# mean       0.321429
# std        3.796187
# min       -9.000000
# 25%       -2.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000
# Name: ref_goals_diff, dtype: float64

# %%
df_club_matches[df_club_matches['ref_result'] > 0]['ref_goals_diff'].hist(bins=range(-40, 40, 1), figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
df_club_matches[df_club_matches['ref_result'] == 0]['ref_goals_diff'].describe()
# Out:
# count    144.000000
# mean       0.201389
# std        3.447062
# min       -7.000000
# 25%       -2.000000
# 50%        0.000000
# 75%        2.000000
# max       15.000000
# Name: ref_goals_diff, dtype: float64

# %%
df_club_matches[df_club_matches['ref_result'] == 0]['ref_goals_diff'].hist(bins=range(-40, 40, 1), figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
df_club_matches[df_club_matches['ref_result'] < 0]['ref_goals_diff'].describe()
# Out:
# count    168.000000
# mean      -0.494048
# std        3.048504
# min       -7.000000
# 25%       -3.000000
# 50%        0.000000
# 75%        1.000000
# max        9.000000
# Name: ref_goals_diff, dtype: float64

# %%
df_club_matches[df_club_matches['ref_result'] < 0]['ref_goals_diff'].hist(bins=range(-40, 40, 1), figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
df_club_matches[(df_club_matches['ref_result'] > 0) & (df_club_matches['ref_id'] == df_club_matches['home_id'])]['ref_goals_diff'].describe()
# Out:
# count    106.000000
# mean      -0.160377
# std        3.588704
# min       -9.000000
# 25%       -2.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000
# Name: ref_goals_diff, dtype: float64

# %%
df_club_matches[(df_club_matches['ref_result'] > 0) & (df_club_matches['ref_id'] == df_club_matches['home_id'])]['ref_goals_diff'].hist(bins=range(-40, 40, 1), figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
df_club_matches[(df_club_matches['ref_result'] == 0) & (df_club_matches['ref_id'] == df_club_matches['home_id'])]['ref_goals_diff'].describe()
# Out:
# count    72.000000
# mean     -0.263889
# std       3.206477
# min      -7.000000
# 25%      -3.000000
# 50%       0.000000
# 75%       2.000000
# max       9.000000
# Name: ref_goals_diff, dtype: float64

# %%
df_club_matches[(df_club_matches['ref_result'] == 0) & (df_club_matches['ref_id'] == df_club_matches['home_id'])]['ref_goals_diff'].hist(bins=range(-40, 40, 1), figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
df_club_matches[(df_club_matches['ref_result'] < 0) & (df_club_matches['ref_id'] == df_club_matches['home_id'])]['ref_goals_diff'].describe()
# Out:
# count    62.000000
# mean     -0.919355
# std       3.158638
# min      -7.000000
# 25%      -4.000000
# 50%       0.000000
# 75%       1.000000
# max       9.000000
# Name: ref_goals_diff, dtype: float64

# %%
df_club_matches[(df_club_matches['ref_result'] < 0) & (df_club_matches['ref_id'] == df_club_matches['home_id'])]['ref_goals_diff'].hist(bins=range(-40, 40, 1), figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
df_club_matches[(df_club_matches['ref_result'] > 0) & (df_club_matches['ref_id'] == df_club_matches['visitor_id'])]['ref_goals_diff'].describe()
# Out:
# count    62.000000
# mean      1.145161
# std       4.023891
# min      -7.000000
# 25%      -1.000000
# 50%       0.000000
# 75%       3.000000
# max      11.000000
# Name: ref_goals_diff, dtype: float64

# %%
df_club_matches[(df_club_matches['ref_result'] > 0) & (df_club_matches['ref_id'] == df_club_matches['visitor_id'])]['ref_goals_diff'].hist(bins=range(-40, 40, 1), figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
df_club_matches[(df_club_matches['ref_result'] == 0) & (df_club_matches['ref_id'] == df_club_matches['visitor_id'])]['ref_goals_diff'].describe()
# Out:
# count    72.000000
# mean      0.666667
# std       3.634731
# min      -7.000000
# 25%      -1.000000
# 50%       0.000000
# 75%       2.250000
# max      15.000000
# Name: ref_goals_diff, dtype: float64

# %%
df_club_matches[(df_club_matches['ref_result'] == 0) & (df_club_matches['ref_id'] == df_club_matches['visitor_id'])]['ref_goals_diff'].hist(bins=range(-40, 40, 1), figsize=(15, 6))
# Out:
# <AxesSubplot:>

# %%
df_club_matches[(df_club_matches['ref_result'] < 0) & (df_club_matches['ref_id'] == df_club_matches['visitor_id'])]['ref_goals_diff'].describe()
# Out:
# count    106.000000
# mean      -0.245283
# std        2.969083
# min       -7.000000
# 25%       -2.000000
# 50%        0.000000
# 75%        1.750000
# max        8.000000
# Name: ref_goals_diff, dtype: float64

# %%
df_club_matches[(df_club_matches['ref_result'] < 0) & (df_club_matches['ref_id'] == df_club_matches['visitor_id'])]['ref_goals_diff'].hist(bins=range(-40, 40, 1), figsize=(15, 6))
# Out:
# <AxesSubplot:>
